# %%
import pandas as pd
import numpy as np

# %%
one = np.array([1, 2, 3, 4, 5])
pd.Series(one)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
Data = {
    "boss": 33,
    "soss": 66,
    "doss": 99
}
pd.Series(Data)
# Out:
# boss    33
# soss    66
# doss    99
# dtype: int64

# %%
sub = np.array(["Mathematics", "Chemistry", "Physics", "History", "Geography", "German"])
grades = np.array([90, 54, 77, 62, 85, 56])
Total_grade = pd.Series(grades, index=sub)
Total_grade
# Out:
# Mathematics    90
# Chemistry      54
# Physics        77
# History        62
# Geography      85
# German         56
# dtype: int64

# %%
maths = {"a":78, "b":88, "c":90, "d":78, "e":72}
grade = pd.Series(maths)
grade[0:5]
# Out:
# a    78
# b    88
# c    90
# d    78
# e    72
# dtype: int64

# %% [markdown]
# data = [['Ali',10], ['baba',12], ['Chali,13']]
# ans = pd.DataFrame(data.columns=['Name','Age'])

# %%
maths = {"a":78, "b":88, "c":90, "d":78, "e":72}
grade = pd.Series(maths)
grade[0:3]
# Out:
# a    78
# b    88
# c    90
# dtype: int64

# %%
data = [['Ali',10],['baba',12],['Chali',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
df
# Out:
#     Name  Age
# 0    Ali   10
# 1   baba   12
# 2  Chali   13

# %%
data = [['Ali','Maths','M',100,'Theory'], ['Benson','English','M',99,'OBJ'], ['Mali','Maths','M',80,'Project'], ['Blessing','Zoology','F',100,'Theory'], ['Alex','Maths','F',100,'Obj & Theory']]
ans = pd.DataFrame(data,columns=['name','subject','gender','score','exam type'])
ans
# Out:
#        name  subject gender  score     exam type
# 0       Ali    Maths      M    100        Theory
# 1    Benson  English      M     99           OBJ
# 2      Mali    Maths      M     80       Project
# 3  Blessing  Zoology      F    100        Theory
# 4      Alex    Maths      F    100  Obj & Theory

# %%
data = [['Ali','Maths','M',100,'Theory'], 
        ['Benson','English','M',99,'OBJ'],
        ['Mali','Maths','M',80,'Project'], 
        ['Blessing','Zoology','F',100,'Theory'], 
        ['Alex','Maths','F',100,'Obj & Theory']]
ans = pd.DataFrame(data,columns=['name','subject','gender','score','exam type'])
ans1 = ans[['score', 'exam type']]
ans1.T
# Out:
#                 0    1        2       3             4
# score         100   99       80     100           100
# exam type  Theory  OBJ  Project  Theory  Obj & Theory

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('drug_consumption.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1885 non-null   int64
#  1   Age        1885 non-null   float64
#  2   Gender     1885 non-null   float64
#  3   Education  1885 non-null   float64
#  4   Country    1885 non-null   float64
#  5   Ethnicity  1885 non-null   float64
#  6   Nscore     1885 non-null   float64
#  7   Escore     1885 non-null   float64
#  8   Oscore     1885 non-null   float64
#  9   Ascore     1885 non-null   float64
#  10  Cscore     1885 non-null   float64
#  11  Impulsive  1885 non-null   float64
#  12  SS         1885 non-null   float64
#  13  Alcohol    1885 non-null   object
#  14  Amphet     1885 non-null   object
#  15  Amyl       1885 non-null   object
#  16  Benzos     1885 non-null   object
#  17  Caff       1885 non-null   object
#  18  Cannabis   1885 non-null   object
#  19  Choc       1885 non-null   object
#  20  Coke       1885 non-null   object
#  21  Crack      1885 non-null   object
#  22  Ecstasy    1885 non-null   object
#  23  Heroin     1885 non-null   object
#  24  Ketamine   1885 non-null   object
#  25  Legalh     1885 non-null   object
#  26  LSD        1885 non-null   object
#  27  Meth       1885 non-null   object
#  28  Mushrooms  1885 non-null   object
#  29  Nicotine   1885 non-null   object
#  30  Semer      1885 non-null   object
#  31  VSA        1885 non-null   object
# dtypes: float64(12), int64(1), object(19)
# memory usage: 471.4+ KB

# %%
df = pd.read_csv('drug_consumption.csv')
df.head(20)
# Out:
#     ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0    1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2    3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4    5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# 5    6  2.59171  0.48246   -1.22751  0.24923   -0.31685 -0.67825 -0.30033
# 6    7  1.09449 -0.48246    1.16365 -0.57009   -0.31685 -0.46725 -1.09207
# 7    8  0.49788 -0.48246   -1.73790  0.96082   -0.31685 -1.32828  1.93886
# 8    9  0.49788  0.48246   -0.05921  0.24923   -0.31685  0.62967  2.57309
# 9   10  1.82213 -0.48246    1.16365  0.96082   -0.31685 -0.24649  0.00332
# 10  11 -0.07854  0.48246    0.45468  0.96082   -0.31685 -1.05308  0.80523
# 11  12  1.09449 -0.48246   -0.61113 -0.28519   -0.31685 -1.32828  0.00332
# 12  13  1.82213  0.48246    0.45468  0.96082   -0.31685  2.28554  0.16767
# 13  14  1.82213  0.48246   -0.05921  0.24923   -0.31685 -0.79151  0.80523
# 14  15  1.82213  0.48246   -0.05921  0.96082   -0.31685 -0.92104  1.45421
# 15  16  1.82213 -0.48246    0.45468  0.96082   -0.31685 -2.05048 -1.50796
# 16  17  0.49788  0.48246   -0.61113  0.96082   -0.31685 -1.55078 -0.80615
# 17  18  1.09449 -0.48246   -1.73790  0.96082   -0.31685  0.52135 -1.23177
# 18  19  1.82213 -0.48246    0.45468 -0.09765   -0.31685  1.37297 -0.15487
# 19  20  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.34799 -1.76250
#
#      Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0  -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1   1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2  -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3  -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4  -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
# 5  -1.55521  2.03972  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 6  -0.45174 -0.30172  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 7  -0.84732 -0.30172  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 8  -0.97631  0.76096  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 9  -1.42424  0.59042  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 10 -1.11902 -0.76096  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 11  0.14143 -1.92595  ...      CL3     CL0       CL0    CL0  CL1  CL0
# 12  0.44585 -1.62090  ...      CL0     CL0       CL0    CL0  CL1  CL1
# 13 -0.01928  0.94156  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 14  0.44585 -0.60633  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 15 -1.55521 -1.07533  ...      CL1     CL0       CL0    CL0  CL0  CL0
# 16 -1.68062  0.28783  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 17 -0.31776 -0.45321  ...      CL1     CL0       CL2    CL0  CL1  CL0
# 18 -0.17779 -1.92595  ...      CL2     CL0       CL0    CL2  CL1  CL0
# 19 -2.39883 -1.92595  ...      CL1     CL0       CL0    CL0  CL0  CL6
#
#    Mushrooms Nicotine Semer  VSA
# 0        CL0      CL2   CL0  CL0
# 1        CL0      CL4   CL0  CL0
# 2        CL1      CL0   CL0  CL0
# 3        CL0      CL2   CL0  CL0
# 4        CL2      CL2   CL0  CL0
# 5        CL0      CL6   CL0  CL0
# 6        CL0      CL6   CL0  CL0
# 7        CL0      CL0   CL0  CL0
# 8        CL0      CL6   CL0  CL0
# 9        CL0      CL6   CL0  CL0
# 10       CL0      CL2   CL0  CL1
# 11       CL2      CL6   CL0  CL0
# 12       CL1      CL6   CL0  CL0
# 13       CL0      CL1   CL0  CL0
# 14       CL0      CL6   CL0  CL0
# 15       CL0      CL0   CL0  CL0
# 16       CL0      CL6   CL0  CL0
# 17       CL1      CL6   CL0  CL0
# 18       CL1      CL0   CL0  CL0
# 19       CL0      CL1   CL0  CL0
#
# [20 rows x 32 columns]

# %%
df = pd.read_csv('drug_consumption.csv')
df.tail(20).T
# Out:
#               1865     1866     1867     1868     1869     1870     1871  \
# ID            1869     1870     1871     1872     1873     1874     1875
# Age       -0.95197 -0.95197 -0.95197 -0.95197 -0.95197 -0.07854 -0.95197
# Gender     0.48246  0.48246  0.48246 -0.48246 -0.48246  0.48246 -0.48246
# Education -0.05921  0.45468 -0.61113 -0.61113 -0.61113  0.45468 -1.22751
# Country   -0.57009 -0.57009 -0.57009 -0.28519 -0.57009 -0.28519 -0.57009
# Ethnicity -0.31685 -0.31685 -0.31685 -0.31685 -0.31685 -0.31685 -0.31685
# Nscore     0.04257  0.13606  1.13281 -0.58016 -0.14882 -1.05308  1.02119
# Escore     0.00332 -0.80615 -0.43999 -0.15487  1.11406  0.96248 -0.43999
# Oscore     2.44904  1.43533  0.29338  0.29338  1.43533  1.88511  1.43533
# Ascore    -0.60633  0.28783 -0.76096  -1.6209 -0.30172  1.81866 -1.07533
# Cscore    -2.18109  1.63088 -0.14277 -1.38502 -0.00665  1.30612  0.12331
# Impulsive  0.88113 -0.71126  1.86203  0.19268  0.19268 -0.71126 -0.71126
# SS          1.2247 -0.21575 -0.21575  0.40148   0.7654  0.07987  0.40148
# Alcohol        CL5      CL6      CL6      CL2      CL3      CL6      CL6
# Amphet         CL0      CL0      CL0      CL4      CL2      CL3      CL3
# Amyl           CL0      CL0      CL2      CL2      CL3      CL1      CL0
# Benzos         CL4      CL0      CL3      CL0      CL3      CL0      CL3
# Caff           CL6      CL6      CL6      CL6      CL5      CL6      CL6
# Cannabis       CL6      CL6      CL6      CL6      CL5      CL5      CL6
# Choc           CL5      CL6      CL4      CL5      CL4      CL4      CL4
# Coke           CL3      CL0      CL3      CL0      CL2      CL0      CL3
# Crack          CL0      CL0      CL2      CL0      CL0      CL0      CL3
# Ecstasy        CL3      CL4      CL2      CL5      CL3      CL3      CL3
# Heroin         CL0      CL0      CL2      CL0      CL0      CL0      CL6
# Ketamine       CL0      CL0      CL0      CL0      CL0      CL0      CL3
# Legalh         CL3      CL4      CL3      CL6      CL3      CL0      CL5
# LSD            CL3      CL3      CL2      CL0      CL3      CL3      CL3
# Meth           CL3      CL0      CL0      CL0      CL4      CL0      CL3
# Mushrooms      CL3      CL3      CL2      CL4      CL3      CL1      CL0
# Nicotine       CL6      CL4      CL6      CL6      CL4      CL5      CL6
# Semer          CL0      CL0      CL0      CL0      CL0      CL0      CL0
# VSA            CL1      CL0      CL0      CL0      CL0      CL0      CL6
#
#               1872     1873     1874     1875     1876     1877     1878  \
# ID            1876     1877     1878     1879     1880     1881     1882
# Age       -0.95197 -0.95197  2.59171 -0.95197 -0.07854 -0.95197 -0.95197
# Gender    -0.48246 -0.48246 -0.48246 -0.48246 -0.48246 -0.48246 -0.48246
# Education -0.61113 -1.43719 -0.61113 -0.61113 -0.61113 -1.43719  0.45468
# Country    0.24923 -0.57009 -0.57009 -0.57009  0.24923 -0.57009  0.24923
# Ethnicity -0.31685 -0.31685 -0.31685    0.126   0.1144 -0.31685 -0.31685
# Nscore    -0.79151  0.73545    2.127 -0.05188 -0.14882  1.49158 -0.05188
# Escore     0.00332 -1.23177 -0.15487  -1.7625 -0.57545 -1.92173  -1.7625
# Oscore     2.44904  0.58331  2.44904  0.58331  1.43533 -0.58331  0.88309
# Ascore     0.76096 -0.60633  0.94156 -0.76096 -0.91699   -1.772 -0.76096
# Cscore     -1.5184 -0.40581 -0.65253 -0.14277 -0.78155  0.58489  2.33337
# Impulsive  0.88113  0.52975 -0.21712  1.29221  0.52975 -0.21712 -0.71126
# SS         1.92173  0.40148  0.07987   1.2247  0.40148   1.2247 -0.21575
# Alcohol        CL5      CL5      CL5      CL5      CL6      CL6      CL4
# Amphet         CL6      CL3      CL0      CL0      CL0      CL2      CL0
# Amyl           CL0      CL0      CL1      CL0      CL0      CL0      CL0
# Benzos         CL0      CL4      CL6      CL0      CL0      CL6      CL0
# Caff           CL5      CL6      CL6      CL5      CL5      CL6      CL2
# Cannabis       CL6      CL6      CL3      CL5      CL6      CL5      CL5
# Choc           CL5      CL5      CL6      CL4      CL5      CL5      CL5
# Coke           CL0      CL3      CL1      CL0      CL4      CL3      CL0
# Crack          CL0      CL2      CL0      CL0      CL0      CL0      CL0
# Ecstasy        CL2      CL3      CL0      CL5      CL3      CL2      CL0
# Heroin         CL0      CL2      CL0      CL0      CL0      CL5      CL0
# Ketamine       CL2      CL0      CL0      CL0      CL3      CL0      CL0
# Legalh         CL2      CL5      CL0      CL2      CL5      CL2      CL2
# LSD            CL0      CL2      CL1      CL4      CL3      CL0      CL0
# Meth           CL0      CL2      CL0      CL0      CL0      CL6      CL0
# Mushrooms      CL0      CL3      CL1      CL4      CL4      CL0      CL2
# Nicotine       CL0      CL6      CL0      CL6      CL2      CL6      CL2
# Semer          CL0      CL0      CL0      CL0      CL0      CL0      CL0
# VSA            CL0      CL2      CL0      CL2      CL2      CL2      CL0
#
#               1879     1880     1881     1882     1883     1884
# ID            1883     1884     1885     1886     1887     1888
# Age       -0.95197 -0.95197 -0.95197 -0.07854 -0.95197 -0.95197
# Gender    -0.48246  0.48246 -0.48246  0.48246  0.48246 -0.48246
# Education -0.61113 -0.61113 -0.61113  0.45468 -0.61113 -0.61113
# Country   -0.28519 -0.57009 -0.57009 -0.57009 -0.57009  0.21128
# Ethnicity -0.31685 -0.31685 -0.31685 -0.31685 -0.31685 -0.31685
# Nscore    -0.79151  -1.1943 -0.24649  1.13281  0.91093 -0.46725
# Escore     0.32197  1.74091  1.74091 -1.37639 -1.92173    2.127
# Oscore     0.29338  1.88511  0.58331 -1.27553  0.29338  1.65653
# Ascore    -0.30172  0.76096  0.76096   -1.772  -1.6209  1.11406
# Cscore    -0.27607 -1.13788  -1.5184 -1.38502 -2.57309  0.41594
# Impulsive  0.88113  0.88113  0.88113  0.52975  1.29221  0.88113
# SS          0.7654  1.92173   0.7654 -0.52593   1.2247   1.2247
# Alcohol        CL4      CL5      CL5      CL4      CL5      CL4
# Amphet         CL3      CL0      CL0      CL6      CL0      CL3
# Amyl           CL0      CL0      CL0      CL5      CL0      CL0
# Benzos         CL3      CL0      CL0      CL5      CL0      CL3
# Caff           CL5      CL4      CL5      CL6      CL6      CL6
# Cannabis       CL6      CL5      CL3      CL6      CL6      CL3
# Choc           CL5      CL4      CL4      CL6      CL5      CL6
# Coke           CL0      CL0      CL0      CL4      CL0      CL3
# Crack          CL0      CL0      CL0      CL0      CL0      CL0
# Ecstasy        CL5      CL0      CL2      CL4      CL3      CL3
# Heroin         CL2      CL0      CL0      CL0      CL0      CL0
# Ketamine       CL0      CL0      CL0      CL2      CL0      CL0
# Legalh         CL4      CL3      CL3      CL0      CL3      CL3
# LSD            CL5      CL3      CL5      CL2      CL3      CL3
# Meth           CL4      CL0      CL4      CL0      CL0      CL0
# Mushrooms      CL0      CL0      CL4      CL2      CL3      CL3
# Nicotine       CL6      CL0      CL5      CL6      CL4      CL6
# Semer          CL0      CL0      CL0      CL0      CL0      CL0
# VSA            CL1      CL5      CL0      CL0      CL0      CL2

# %%
import mysql.connector as sql
import pandas as pd

# %%
host="courses.csrrinzqubik.us-east-1.rds.amazonaws.com"
dt = sql.connect(host=host, port= "3306", database="tweater", user="student", password="datacamp")

db_cursor=dt.cursor()
db_cursor.execute('SELECT*FROM tweats')

table_rows = db_cursor.fetchall()
df = pd.DataFrame(table_rows)
df
# Out:
#     0  1                                                  2           3
# 0  75  3                      break egg. bake egg. eat egg.  2015-09-05
# 1  88  4          wash strawberries. add ice. blend. enjoy.  2015-09-14
# 2  77  6      2 slices of bread. add cheese. grill. heaven.  2015-09-21
# 3  87  5  open and crush avocado. add shrimps. perfect s...  2015-09-22
# 4  49  1  nachos. add tomato sauce, minced meat and chee...  2015-09-22
# 5  24  7             just eat an apple. simply and healthy.  2015-09-24

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in /home/solomon/.local/lib/python3.10/site-packages (8.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd

host = "car-simulation-station.c9az8e0qjbgo.us-east-1.rds.amazonaws.com"
database = "car_simulation_station"
user = "datacamp_user"
password = "learn tabular data for fun and profit"


connection = mysql.connector.connect(
    host=host,
    port=3306,
    database=database,
    user=user,
    password=password
)

db_cursor = connection.cursor()
db_cursor.execute('SELECT * FROM all')


table_rows = db_cursor.fetchall()
df = pd.DataFrame(table_rows)


db_cursor.close()
connection.close()



print(df)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host 'car-simulation-station.c9az8e0qjbgo.us-east-1.rds.amazonaws.com' (-2)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 10
#       6 user = "datacamp_user"
#       7 password = "learn tabular data for fun and profit"
# ---> 10 connection = mysql.connector.connect(
#      11     host=host,
#      12     port=3306,
#      13     database=database,
#      14     user=user,
#      15     password=password
#      16 )
#      18 db_cursor = connection.cursor()
#      19 db_cursor.execute('SELECT * FROM all')
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:140, in CMySQLConnection.__init__(self, **kwargs)
#     138 if kwargs:
#     139     try:
# --> 140         self.connect(**kwargs)
#     141     except Exception:
#     142         self.close()
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/abstracts.py:1363, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1360     self.config(**kwargs)
#    1362 self.disconnect()
# -> 1363 self._open_connection()
#    1365 charset, collation = (
#    1366     kwargs.pop("charset", None),
#    1367     kwargs.pop("collation", None),
#    1368 )
#    1369 if charset or collation:
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:328, in CMySQLConnection._open_connection(self)
#     326         self.converter.str_fallback = self._converter_str_fallback
#     327 except MySQLInterfaceError as err:
# --> 328     raise get_mysql_exception(
#     329         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     330     ) from err
#     332 self._do_handshake()
#
# DatabaseError: 2005 (HY000): Unknown MySQL server host 'car-simulation-station.c9az8e0qjbgo.us-east-1.rds.amazonaws.com' (-2)

# %%
import requests
import pandas as pd
response = requests.get("https://www.givefood.org.uk/api/2/foodbanks")


print(response.status_code)
food_json = response.json()

food_dataframe = pd.json_normalize(food_json)
food_dataframe.shape
food_dataframe.head()
# Out:
# 200
#                          name alt_name              slug        phone  \
# 0          Chiltern Food Bank     None          chiltern  01494775668
# 1            Barrow Food Bank     None            barrow  01229343436
# 2              Noor Food Bank     None              noor         None
# 3  Bradford on Avon Food Bank     None  bradford-on-avon  01225920748
# 4    Lions Food Hub Food Bank     None    lions-food-hub  02077400503
#
#   secondary_phone                                email  \
# 0            None        info@chiltern.foodbank.org.uk
# 1            None  projectmanager@barrowfoodbank.co.uk
# 2            None             hello@noorfoodbank.co.uk
# 3            None            boacommunityhub@gmail.com
# 4            None               lionsfoodhub@gmail.com
#
#                                              address  postcode  closed  \
# 0  71 Broadway\r\nChesham\r\nBuckinghamshire\r\nH...   HP5 1BX   False
# 1  Abbey Road Baptist Church\r\nAbbey Road\r\nBar...  LA13 9BD   False
# 2         Noor Hall\r\nNoor St\r\nPreston\r\nPR1 1QS   PR1 1QS   False
# 3  The Hub @ BA15\r\nChurch Street\r\nBradford on...  BA15 1LS   False
# 4  Millwall Community Trust\r\nBolina Road\r\nSE1...  SE16 3LD   False
#
#    country  ... charity.registration_id  \
# 0  England  ...                 1146699
# 1  England  ...                 1152753
# 2  England  ...                    None
# 3  England  ...                 1160807
# 4  England  ...                    None
#
#                                 charity.register_url  \
# 0  https://register-of-charities.charitycommissio...
# 1  https://register-of-charities.charitycommissio...
# 2                                               None
# 3  https://register-of-charities.charitycommissio...
# 4                                               None
#
#   politics.parliamentary_constituency       politics.mp    politics.mp_party  \
# 0                Chesham and Amersham       Sarah Green    Liberal Democrats
# 1                  Barrow and Furness        Simon Fell         Conservative
# 2                             Preston     Mark Hendrick  Labour Co-operative
# 3                          Chippenham  Michelle Donelan         Conservative
# 4                  Lewisham, Deptford    Vicky Foxcroft               Labour
#
#   politics.mp_parl_id           politics.ward        politics.district  \
# 0              4918.0            Chess Valley          Buckinghamshire
# 1              4744.0   Ormsgill and Parkside  Westmorland and Furness
# 2               473.0            St Matthew's                  Preston
# 3              4530.0  Bradford-on-Avon South                Wiltshire
# 4              4491.0          New Cross Gate                 Lewisham
#
#                                   politics.urls.self  \
# 0  https://www.givefood.org.uk/api/2/constituency...
# 1  https://www.givefood.org.uk/api/2/constituency...
# 2  https://www.givefood.org.uk/api/2/constituency...
# 3  https://www.givefood.org.uk/api/2/constituency...
# 4  https://www.givefood.org.uk/api/2/constituency...
#
#                                   politics.urls.html
# 0  https://www.givefood.org.uk/needs/in/constitue...
# 1  https://www.givefood.org.uk/needs/in/constitue...
# 2  https://www.givefood.org.uk/needs/in/constitue...
# 3  https://www.givefood.org.uk/needs/in/constitue...
# 4  https://www.givefood.org.uk/needs/in/constitue...
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#                0         1
# count   6.000000  6.000000
# mean   66.666667  4.333333
# std    25.208464  2.160247
# min    24.000000  1.000000
# 25%    55.500000  3.250000
# 50%    76.000000  4.500000
# 75%    84.500000  5.750000
# max    88.000000  7.000000

# %%
df.describe().T
# Out:
#    count       mean        std   min    25%   50%    75%   max
# 0    6.0  66.666667  25.208464  24.0  55.50  76.0  84.50  88.0
# 1    6.0   4.333333   2.160247   1.0   3.25   4.5   5.75   7.0

# %%
import requests
import pandas as pd
response = requests.get("https://www.givefood.org.uk/api/2/foodbanks")


print(response.status_code)
food_json = response.json()

food_dataframe = pd.json_normalize(food_json)
food_dataframe.shape
food_dataframe.head().T
# Out:
# 200
#                                                                                      0  \
# name                                                                Chiltern Food Bank
# alt_name                                                                          None
# slug                                                                          chiltern
# phone                                                                      01494775668
# secondary_phone                                                                   None
# email                                                    info@chiltern.foodbank.org.uk
# address                              71 Broadway\r\nChesham\r\nBuckinghamshire\r\nH...
# postcode                                                                       HP5 1BX
# closed                                                                           False
# country                                                                        England
# lat_lng                                                 51.7060815,-0.6119340999999999
# network                                                                 Trussell Trust
# created                                                        2019-12-20T08:53:36.944
# urls.self                            https://www.givefood.org.uk/api/2/foodbank/chi...
# urls.html                               https://www.givefood.org.uk/needs/at/chiltern/
# urls.homepage                                         https://chiltern.foodbank.org.uk
# urls.shopping_list                   https://chiltern.foodbank.org.uk/give-help/don...
# charity.registration_id                                                        1146699
# charity.register_url                 https://register-of-charities.charitycommissio...
# politics.parliamentary_constituency                               Chesham and Amersham
# politics.mp                                                                Sarah Green
# politics.mp_party                                                    Liberal Democrats
# politics.mp_parl_id                                                             4918.0
# politics.ward                                                             Chess Valley
# politics.district                                                      Buckinghamshire
# politics.urls.self                   https://www.givefood.org.uk/api/2/constituency...
# politics.urls.html                   https://www.givefood.org.uk/needs/in/constitue...
#
#                                                                                      1  \
# name                                                                  Barrow Food Bank
# alt_name                                                                          None
# slug                                                                            barrow
# phone                                                                      01229343436
# secondary_phone                                                                   None
# email                                              projectmanager@barrowfoodbank.co.uk
# address                              Abbey Road Baptist Church\r\nAbbey Road\r\nBar...
# postcode                                                                      LA13 9BD
# closed                                                                           False
# country                                                                        England
# lat_lng                                                          54.1206385,-3.2197493
# network                                                                 Trussell Trust
# created                                                        2020-01-13T12:10:15.223
# urls.self                            https://www.givefood.org.uk/api/2/foodbank/bar...
# urls.html                                 https://www.givefood.org.uk/needs/at/barrow/
# urls.homepage                                           https://barrow.foodbank.org.uk
# urls.shopping_list                   https://barrow.foodbank.org.uk/give-help/donat...
# charity.registration_id                                                        1152753
# charity.register_url                 https://register-of-charities.charitycommissio...
# politics.parliamentary_constituency                                 Barrow and Furness
# politics.mp                                                                 Simon Fell
# politics.mp_party                                                         Conservative
# politics.mp_parl_id                                                             4744.0
# politics.ward                                                    Ormsgill and Parkside
# politics.district                                              Westmorland and Furness
# politics.urls.self                   https://www.givefood.org.uk/api/2/constituency...
# politics.urls.html                   https://www.givefood.org.uk/needs/in/constitue...
#
#                                                                                      2  \
# name                                                                    Noor Food Bank
# alt_name                                                                          None
# slug                                                                              noor
# phone                                                                             None
# secondary_phone                                                                   None
# email                                                         hello@noorfoodbank.co.uk
# address                                     Noor Hall\r\nNoor St\r\nPreston\r\nPR1 1QS
# postcode                                                                       PR1 1QS
# closed                                                                           False
# country                                                                        England
# lat_lng                                                          53.7657864,-2.6948046
# network                                                                           IFAN
# created                                                        2020-08-30T09:54:13.393
# urls.self                             https://www.givefood.org.uk/api/2/foodbank/noor/
# urls.html                                   https://www.givefood.org.uk/needs/at/noor/
# urls.homepage                                               https://noorfoodbank.co.uk
# urls.shopping_list                                         https://noorfoodbank.co.uk/
# charity.registration_id                                                           None
# charity.register_url                                                              None
# politics.parliamentary_constituency                                            Preston
# politics.mp                                                              Mark Hendrick
# politics.mp_party                                                  Labour Co-operative
# politics.mp_parl_id                                                              473.0
# politics.ward                                                             St Matthew's
# politics.district                                                              Preston
# politics.urls.self                   https://www.givefood.org.uk/api/2/constituency...
# politics.urls.html                   https://www.givefood.org.uk/needs/in/constitue...
#
#                                                                                      3  \
# name                                                        Bradford on Avon Food Bank
# alt_name                                                                          None
# slug                                                                  bradford-on-avon
# phone                                                                      01225920748
# secondary_phone                                                                   None
# email                                                        boacommunityhub@gmail.com
# address                              The Hub @ BA15\r\nChurch Street\r\nBradford on...
# postcode                                                                      BA15 1LS
# closed                                                                           False
# country                                                                        England
# lat_lng                                                          51.3478187,-2.2514713
# network                                                                 Trussell Trust
# created                                                        2020-01-20T10:58:30.695
# urls.self                            https://www.givefood.org.uk/api/2/foodbank/bra...
# urls.html                            https://www.givefood.org.uk/needs/at/bradford-...
# urls.homepage                                   https://bradfordonavon.foodbank.org.uk
# urls.shopping_list                   https://bradfordonavon.foodbank.org.uk/give-he...
# charity.registration_id                                                        1160807
# charity.register_url                 https://register-of-charities.charitycommissio...
# politics.parliamentary_constituency                                         Chippenham
# politics.mp                                                           Michelle Donelan
# politics.mp_party                                                         Conservative
# politics.mp_parl_id                                                             4530.0
# politics.ward                                                   Bradford-on-Avon South
# politics.district                                                            Wiltshire
# politics.urls.self                   https://www.givefood.org.uk/api/2/constituency...
# politics.urls.html                   https://www.givefood.org.uk/needs/in/constitue...
#
#                                                                                      4
# name                                                          Lions Food Hub Food Bank
# alt_name                                                                          None
# slug                                                                    lions-food-hub
# phone                                                                      02077400503
# secondary_phone                                                                   None
# email                                                           lionsfoodhub@gmail.com
# address                              Millwall Community Trust\r\nBolina Road\r\nSE1...
# postcode                                                                      SE16 3LD
# closed                                                                           False
# country                                                                        England
# lat_lng                                                          51.4869877,-0.0523671
# network                                                                    Independent
# created                                                        2022-07-04T14:47:31.926
# urls.self                            https://www.givefood.org.uk/api/2/foodbank/lio...
# urls.html                            https://www.givefood.org.uk/needs/at/lions-foo...
# urls.homepage                                   https://www.bankuet.co.uk/lionsfoodhub
# urls.shopping_list                              https://www.bankuet.co.uk/lionsfoodhub
# charity.registration_id                                                           None
# charity.register_url                                                              None
# politics.parliamentary_constituency                                 Lewisham, Deptford
# politics.mp                                                             Vicky Foxcroft
# politics.mp_party                                                               Labour
# politics.mp_parl_id                                                             4491.0
# politics.ward                                                           New Cross Gate
# politics.district                                                             Lewisham
# politics.urls.self                   https://www.givefood.org.uk/api/2/constituency...
# politics.urls.html                   https://www.givefood.org.uk/needs/in/constitue...
